# %%
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from modules.prediction import load_all_data
from modules.prediction import precrime_train_test_split
from modules.prediction import create_test_quarter, create_finegrained_split, create_coarsegrained_split

# %%
crime_data = load_all_data()
# Out:
# /Users/jsamet/anaconda2/envs/py3k/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
test_finegrained = create_finegrained_split()

# %%
X_train, X_test, y_train, y_test = precrime_train_test_split(crime_data, test_finegrained)

# %%
X_train
# Out:
#          COMPLAINT_YEAR  COMPLAINT_MONTH  COMPLAINT_DAY  COMPLAINT_HOURGROUP  \
# 0                  2006                1              2                    0
# 1                  2006                1              2                    0
# 2                  2006                1              2                    0
# 3                  2006                1              2                    0
# 4                  2006                1              2                    0
# 5                  2006                1              2                    0
# 6                  2006                1              2                    0
# 7                  2006                1              2                    0
# 8                  2006                1              2                    0
# 9                  2006                1              2                    0
# 10                 2006                1              2                    0
# ...

# %%
X_test
# Out:
#          COMPLAINT_YEAR  COMPLAINT_MONTH  COMPLAINT_DAY  COMPLAINT_HOURGROUP  \
# 231                2006                1              2                   12
# 232                2006                1              2                   12
# 233                2006                1              2                   12
# 234                2006                1              2                   12
# 235                2006                1              2                   12
# 236                2006                1              2                   12
# 237                2006                1              2                   12
# 238                2006                1              2                   12
# 239                2006                1              2                   12
# 240                2006                1              2                   12
# 241                2006                1              2                   12
# ...

# %%
X_train, X_test, y_train, y_test = precrime_train_test_split(crime_data, test_df)

# %%
len(X_train)
# Out:
# 1670361

# %%
len(X_test)
# Out:
# 185493

# %%
185493 * 9
# Out:
# 1669437

# %%
5/44
# Out:
# 0.11363636363636363

# %%
create_coarsegrained_split()
# Out:
#       TEST_YEAR  TEST_MONTH  TEST_DAY  TEST_HOURGROUP
# 0          2011           1         1               0
# 1          2011           1         1               4
# 2          2011           1         1               8
# 3          2011           1         1              12
# 4          2011           1         1              16
# 5          2011           1         1              20
# 6          2011           1         2               0
# 7          2011           1         2               4
# 8          2011           1         2               8
# 9          2011           1         2              12
# 10         2011           1         2              16
# 11         2011           1         2              20
# 12         2011           1         3               0
# 13         2011           1         3               4
# 14         2011           1         3               8
# 15         2011           1         3              12
# ...
