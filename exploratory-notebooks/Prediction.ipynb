# %%
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from modules.prediction import load_all_data, split_into_X_y

# %%
crime_data = load_all_data()
# Out:
# /Users/jsamet/anaconda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
def create_test_quarter(year, quarter):
    first_date = datetime.date(year, 3 * (quarter-1) + 1, 1)
    if quarter == 4:
        last_date = datetime.date(year+1, 1, 1)
    else:
        last_date = datetime.date(year, 3 * quarter + 1, 1)
    one_day = datetime.timedelta(days=1)
    dates_in_dataset = []
    d = first_date
    while d < last_date:
        dates_in_dataset.append(d)
        d += one_day
    print(dates_in_dataset)

# %%
create_test_quarter(2017,3)
# Out:
# [datetime.date(2017, 7, 1), datetime.date(2017, 7, 2), datetime.date(2017, 7, 3), datetime.date(2017, 7, 4), datetime.date(2017, 7, 5), datetime.date(2017, 7, 6), datetime.date(2017, 7, 7), datetime.date(2017, 7, 8), datetime.date(2017, 7, 9), datetime.date(2017, 7, 10), datetime.date(2017, 7, 11), datetime.date(2017, 7, 12), datetime.date(2017, 7, 13), datetime.date(2017, 7, 14), datetime.date(2017, 7, 15), datetime.date(2017, 7, 16), datetime.date(2017, 7, 17), datetime.date(2017, 7, 18), datetime.date(2017, 7, 19), datetime.date(2017, 7, 20), datetime.date(2017, 7, 21), datetime.date(2017, 7, 22), datetime.date(2017, 7, 23), datetime.date(2017, 7, 24), datetime.date(2017, 7, 25), datetime.date(2017, 7, 26), datetime.date(2017, 7, 27), datetime.date(2017, 7, 28), datetime.date(2017, 7, 29), datetime.date(2017, 7, 30), datetime.date(2017, 7, 31), datetime.date(2017, 8, 1), datetime.date(2017, 8, 2), datetime.date(2017, 8, 3), datetime.date(2017, 8, 4), datetime.date(2017, 8, 5), dat
# ...

# %%
test_df = pd.DataFrame([
    {'TEST_YEAR': 2016, 'TEST_MONTH': 12, 'TEST_DAY': 31, 'TEST_HOURGROUP': 20}
])

# %%
from modules.prediction import precrime_train_test_split

# %%
X_train, X_test, y_train, y_test = precrime_train_test_split(crime_data, test_df)

# %%
X_train
# Out:
#          COMPLAINT_YEAR  COMPLAINT_MONTH  COMPLAINT_DAY  COMPLAINT_HOURGROUP  \
# 0                  2006                1              2                    0
# 1                  2006                1              2                    0
# 2                  2006                1              2                    0
# 3                  2006                1              2                    0
# 4                  2006                1              2                    0
# 5                  2006                1              2                    0
# 6                  2006                1              2                    0
# 7                  2006                1              2                    0
# 8                  2006                1              2                    0
# 9                  2006                1              2                    0
# 10                 2006                1              2                    0
# ...

# %%
X_test
# Out:
#          COMPLAINT_YEAR  COMPLAINT_MONTH  COMPLAINT_DAY  COMPLAINT_HOURGROUP  \
# 1855777            2016               12             31                   20
# 1855778            2016               12             31                   20
# 1855779            2016               12             31                   20
# 1855780            2016               12             31                   20
# 1855781            2016               12             31                   20
# 1855782            2016               12             31                   20
# 1855783            2016               12             31                   20
# 1855784            2016               12             31                   20
# 1855785            2016               12             31                   20
# 1855786            2016               12             31                   20
# 1855787            2016               12             31                   20
# ...
